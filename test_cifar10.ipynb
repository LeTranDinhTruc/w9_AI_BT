# %% [markdown]
# <a href="https://colab.research.google.com/github/LeTranDinhTruc/w9_AI_BT/blob/main/test_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import load_img, img_to_array
from keras.models import load_model
img=load_img('/content/drive/MyDrive/AI/images.jfif',target_size=(32,32,3))
plt.imshow(img)
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')
img=img/255
model=load_model('/content/drive/MyDrive/AI/test1.h5')
np.argmax(model.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 201ms/step
# array([9])
